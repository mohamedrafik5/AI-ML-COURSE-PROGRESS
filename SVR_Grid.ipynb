# %% [markdown]
# <a href="https://colab.research.google.com/github/mohamedrafik5/AI-ML-COURSE-PROGRESS/blob/main/SVR_Grid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing the Libraies
import numpy as np
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('/content/insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid = param_grid = {
    'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
    'C': [1, 10, 100, 1000],
    'gamma': ['scale', 'auto']
}
grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3 ,n_jobs=-1)
# fitting the model for grid search
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [1, 10, 100, 1000], 'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid']},
#              verbose=3)
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [1, 10, 100, 1000], 'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid']},
#              verbose=3)

# %%
from sklearn.model_selection import GridSearchCV

# Assuming 'grid' is your GridSearchCV object and has been fitted to the data
print("Best parameters:", grid.best_params_)

# Access the mean test score for the best parameters
best_index = grid.best_index_
best_r2_score = grid.cv_results_['mean_test_score'][best_index]
# Printing the best R² score
print("r2:",best_r2_score)
# Out:
# Best parameters: {'C': 1000, 'gamma': 'scale', 'kernel': 'poly'}
# r2: 0.7878080009651789
# Best parameters: {'C': 1000, 'gamma': 'scale', 'kernel': 'poly'}
# r2: 0.7878080009651799

# %%
table=pd.DataFrame.from_dict(grid.cv_results_)

# %%
table[['rank_test_score', 'mean_test_score', 'params']].sort_values('rank_test_score')
# Out:
#     rank_test_score  mean_test_score  \
# 25                1         0.787808
# 29                2         0.787499
# 30                3         0.691544
# 26                4         0.691485
# 28                5         0.600119
# 24                5         0.600119
# 20                7         0.585008
# 16                7         0.585008
# 17                9         0.506299
# 21               10         0.506281
# 23               11         0.474000
# 19               12         0.473708
# 12               13         0.355112
# 8                13         0.355112
# 27               15         0.315846
# 31               16         0.282901
# 22               17         0.229703
# 18               18         0.229672
# 9                19         0.000877
# 13               20         0.000826
# 11               21        -0.004968
# 15               22        -0.004978
# 4                23        -0.039827
# 0                23        -0.039827
# ...

# %%
# Assuming 'grid' is your GridSearchCV object that has been fitted to the data
best_model = grid.best_estimator_

# %%
from sklearn.metrics import r2_score, mean_squared_error

# Make predictions on the test set
y_pred = best_model.predict(X_test)

# Calculate R-squared
r2 = r2_score(y_test, y_pred)

# Calculate Mean Squared Error
mse = mean_squared_error(y_test, y_pred)

print(f"R-squared: {r2}")
print(f"Mean Squared Error: {mse}")
# Out:
# R-squared: 0.8519826487890426
# Mean Squared Error: 23732391.708481263

# %%
import pickle
filename="SVR_G.sav"
pickle.dump(best_model,open(filename,'wb'))

# %%
# Get input from the user
age = int(input("Enter age: "))
bmi = float(input("Enter BMI: "))
children = int(input("Enter number of children: "))
sex_male = int(input("Enter 1 for male, 0 for female: "))
smoker_yes = int(input("Enter 1 for smoker, 0 for non-smoker: "))
# Out:
# Enter age: 19
# Enter BMI: 27.900
# Enter number of children: 0
# Enter 1 for male, 0 for female: 0
# Enter 1 for smoker, 0 for non-smoker: 1

# %%
# Load the saved model
loaded_model = pickle.load(open(filename, 'rb'))

# Create a numpy array from the user input
input_data = np.array([[age, bmi, children, sex_male, smoker_yes]])

# Convert the input array to a DataFrame with the correct column names
input_df = pd.DataFrame(input_data, columns=['age', 'bmi', 'children', 'sex_male', 'smoker_yes'])

# Scale the input data using the same scaler fitted on the training data
scaled_input_data = sc.transform(input_df)

# Make a prediction
predicted_charge = loaded_model.predict(scaled_input_data)

print(f"The predicted insurance charge is: {predicted_charge[0]}")
# Out:
# The predicted insurance charge is: 19020.661542502836
# The predicted insurance charge is: 2170849.5270526092
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
